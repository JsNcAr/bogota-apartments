# %%
from dotenv import load_dotenv
import pandas as pd
import numpy as np
from folium.plugins import HeatMap
from folium.plugins import MarkerCluster
from folium import plugins
import matplotlib.pyplot as plt
from matplotlib import patches
from matplotlib.patches import FancyArrowPatch
import scipy.stats as stats
import pymongo
import seaborn as sns
import humanize
import warnings
import matplotlib.colors as mcolors  # For color interpolation
import folium
import os

# %%
warnings.filterwarnings('ignore')

load_dotenv()
# Out:
# True

# %%
title_font = {"fontname":"Nimbus Sans", "size":18, "color":"midnightblue"}
subtitle_font = {"fontname":"Roboto", "size":14, "color":"rebeccapurple"}
text_font = {"fontname": "DejaVu Sans", "size": 12, "color": "dimgray"}  # Ajustar el color para ser más coherente con el estilo general

# Ajustar el estilo de Seaborn
sns.set_style('ticks', {
    'axes.grid': True,
    'grid.color': '0.8',  # Color claro para la rejilla
    'grid.linestyle': '--',
    'grid.linewidth': 0.6,
    'font.sans-serif': ['Nimbus Sans', 'DejaVu Sans', 'Liberation Sans', 'Bitstream Vera Sans', 'sans-serif'],
    'axes.edgecolor': '0.5'  # Ajustar el color de los bordes de los ejes para que sea suave
})

# Ajustar la resolución de la imagen
plt.rcParams['figure.dpi'] = 80

# %%
apartments = pd.read_csv('../data/processed/apartments.csv')
print(apartments.shape)
apartments = apartments.loc[(apartments['tipo_operacion'] == 'ARRIENDO') & (apartments['coords_modified'] == False)]
apartments = apartments.drop(['precio_venta', 'tipo_operacion', 'coords_modified'], axis=1)
apartments.head()
# Out:
# (19551, 45)
#               codigo tipo_propiedad   area  habitaciones  banos  \
# 9724       MC5214856    APARTAMENTO  106.0           3.0    2.0
# 9725       MC5226855    APARTAMENTO   70.0           3.0    2.0
# 9726       MC5224821    APARTAMENTO   44.5           1.0    1.0
# 9727       MC3587458    APARTAMENTO   43.0           1.0    1.0
# 9728  15234-M5227729    APARTAMENTO  212.0           4.0    4.0
#
#       administracion  parqueaderos                sector  estrato  \
# 9724        560000.0           2.0  COLINA Y ALREDEDORES      4.0
# 9725        300000.0           1.0       SALITRE MODELIA      4.0
# 9726        391000.0           1.0         SANTA BARBARA      6.0
# 9727             NaN           1.0            LA SOLEDAD      4.0
# 9728             NaN           2.0                 CHICO      6.0
#
#               antiguedad  ...  terraza  vigilancia    localidad  \
# 9724   ENTRE 5 Y 10 ANOS  ...        0           0         SUBA
# 9725      MAS DE 20 ANOS  ...        0           0     FONTIBON
# 9726  ENTRE 10 Y 20 ANOS  ...        0           0      USAQUEN
# 9727    ENTRE 0 Y 5 ANOS  ...        0           0  TEUSAQUILLO
# 9728      MAS DE 20 ANOS  ...        0           1    CHAPINERO
#
#                             barrio       estacion_tm_cercana  \
# 9724      S.C. CIUDAD JARDIN NORTE         Suba - AV. Boyacá
# 9725                     SAUZALITO  Av. Rojas – UNISALESIANA
# 9726  SANTA BARBARA CENTRAL I Y II                 Calle 106
# 9727                       ARMENIA                  Calle 26
# 9728                    LA CABRERA                    Héroes
#
#      distancia_estacion_tm_m is_cerca_estacion_tm  \
# 9724                  258.77                    1
# 9725                  641.89                    0
# 9726                 1586.97                    0
# 9727                  141.86                    1
# 9728                 1480.54                    0
#
#                                          parque_cercano distancia_parque_m  \
# 9724  PARQUE VECINAL AGRUPACIÓN DE VIVIENDA EN BALCO...            1169.15
# 9725            PARQUE VECINAL CARLOS LLERAS (EL FUEGO)             205.51
# 9726                    PARQUE METROPOLITANO EL COUNTRY            1714.01
# 9727  PARQUE METROPOLITANO EL RENACIMIENTO - PARQUE ...             445.06
# 9728             PARQUE VECINAL URBANIZACIÓN LA CABRERA             494.38
#
#      is_cerca_parque
# 9724               0
# 9725               1
# 9726               0
# 9727               1
# 9728               1
#
# [5 rows x 42 columns]

# %%
apartments.columns
# Out:
# Index(['codigo', 'tipo_propiedad', 'area', 'habitaciones', 'banos',
#        'administracion', 'parqueaderos', 'sector', 'estrato', 'antiguedad',
#        'latitud', 'longitud', 'direccion', 'descripcion', 'website',
#        'last_view', 'datetime', 'url', 'timeline', 'estado', 'compañia',
#        'precio_arriendo', 'jacuzzi', 'piso', 'closets', 'chimenea',
#        'permite_mascotas', 'gimnasio', 'ascensor', 'conjunto_cerrado',
#        'piscina', 'salon_comunal', 'terraza', 'vigilancia', 'localidad',
#        'barrio', 'estacion_tm_cercana', 'distancia_estacion_tm_m',
#        'is_cerca_estacion_tm', 'parque_cercano', 'distancia_parque_m',
#        'is_cerca_parque'],
#       dtype='object')

# %%
apartments['datetime'] = pd.to_datetime(apartments['datetime'])

# %%
fotmat_tick_humanize = lambda x, pos: humanize.intword(x)

# %% [markdown]
# # Removing Outliers

# %%
apartments['precio_arriendo'].describe().apply(lambda x: humanize.intword(x))
# Out:
# count      9.1 thousand
# mean       15.3 million
# std       267.2 million
# min      550.0 thousand
# 25%         2.2 million
# 50%         4.5 million
# 75%         9.0 million
# max        16.9 billion
# Name: precio_arriendo, dtype: object

# %%
Q1 = apartments['precio_arriendo'].quantile(0.25)
Q3 = apartments['precio_arriendo'].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.8 * IQR
upper = Q3 + 1.8 * IQR

if lower < 0:
    lower = Q1 - 0.4 * IQR

outliers = apartments.loc[(apartments['precio_arriendo'] < lower) | (
    apartments['precio_arriendo'] > upper)]
outliers.shape
# lower, upper
# Out:
# (321, 42)

# %%
# Porcentaje de outliers
print(
    f"Porcentaje de outliers: {round(outliers.shape[0] / apartments.shape[0], 5) *100} %")
# Out:
# Porcentaje de outliers: 3.517 %

# %%
apartments = apartments[(apartments['precio_arriendo'] > lower) & (
    apartments['precio_arriendo'] < upper)]
apartments.shape
# Out:
# (8805, 42)

# %%
apartments['precio_arriendo'].describe().apply(
    lambda x: humanize.intword(x)).to_frame()
# Out:
#       precio_arriendo
# count    8.8 thousand
# mean      5.8 million
# std       4.7 million
# min    550.0 thousand
# 25%       2.2 million
# 50%       4.3 million
# 75%       8.0 million
# max      21.2 million

# %% [markdown]
# ## Create map

# %%
# Create a base map centered around Bogotá
m = folium.Map(location=[4.7110, -74.0721], zoom_start=12)

# %%
# Prepare data for heatmap
heat_data = [[row['latitud'], row['longitud']]
             for index, row in apartments.iterrows()]

# Add a heatmap to the base map
HeatMap(heat_data).add_to(m)

m.save('../visualizations/heatmap.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f42850cee562bd55a209b455170eca21 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f42850cee562bd55a209b455170eca21&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f42850cee562bd55a209b455170eca21 = L.map(
#                 &quot;map_f42850cee562bd55a209b455170eca21&quot;,
#                 {
#                     center: [4.711, -74.0721],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3475c4ff44728e049ec13a1b5ae42b37 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_3475c4ff44728e049ec13a1b5ae42b37.addTo(map_f42850cee562bd55a209b455170eca21);
#
#
#             var heat_map_f51fed20e2d612f7473fb637cedc5bb1 = L.heatLayer(
#                 [[4.7226987, -74.072815], [4.6580687, -74.113045], [4.689426, -74.04231], [4.617431, -74.07316], [4.66715, -74.04699], [4.6557336, -74.13011], [4.6633315, -74.06292], [4.6084027, -74.08185], [4.6834397, -74.05646], [4.7325454, -74.11713], [4.6395, -74.14014], [4.70287, -74.05235], [4.75923, -74.10156], [4.7520146, -74.10153], [4.5672, -74.12449], [4.65536, -74.11115], [4.65012, -74.07316], [4.7012777, -74.05169], [4.701353, -74.05111], [4.674065, -74.04865], [4.746681, -74.023506], [4.6149063, -74.06656], [4.6539536, -74.108376], [4.6879315, -74.049355], [4.6461115, -74.05352], [4.680802, -74.0452], [4.708323, -74.051254], [4.6996927, -74.06341], [4.69369, -74.16286], [4.587663, -74.105484], [4.6567283, -74.11191], [4.655, -74.05], [4.727358, -74.0368], [4.7469616, -74.063194], [4.723271, -74.0342], [4.638662, -74.06323], [4.68016, -74.0509], [4.6963716, -74.061905], [4.742134, -74.06158], [4.634588, -74.129196], [4.73069, -74.036865], [4.674422, -74.05629], [4.66494, -74.02542], [4.6425643, -74.11078], [4.65809, -74.06183], [4.70037, -74.06289], [4.73494, -74.09091], [4.74996, -74.06556], [4.661, -74.053], [4.6586204, -74.05142], [4.7, -74.037], [4.66066, -74.11921], [4.658, -74.057], [4.6759152, -74.057686], [4.658427, -74.06183], [4.703229, -74.0275], [4.6529603, -74.05239], [4.6946254, -74.05501], [4.723543, -74.03714], [4.66279, -74.13458], [4.631597, -74.06232], [4.69452, -74.04229], [4.6987567, -74.048355], [4.726994, -74.04148], [4.5874896, -74.12654], [4.7022004, -74.04678], [4.75598, -74.11482], [4.68749, -74.15405], [4.6387, -74.06205], [4.65565, -74.07712], [4.72192, -74.05823], [4.716288, -74.027466], [4.69862, -74.05378], [4.654815, -74.05527], [4.67003, -74.04724], [4.64643, -74.13942], [4.6768637, -74.04197], [4.7145576, -74.037674], [4.6734223, -74.04988], [4.700797, -74.03783], [4.72421, -74.05003], [4.6802344, -74.052414], [4.708, -74.043], [4.677486, -74.04398], [4.6763625, -74.05402], [4.6576724, -74.05212], [4.6461644, -74.062546], [4.65527, -74.05185], [4.744739, -74.06918], [4.57546, -74.10337], [4.67456, -74.05515], [4.6616793, -74.052444], [4.6453, -74.06509], [4.621696, -74.12091], [4.710284, -74.033226], [4.683058, -74.1079], [4.73116, -74.06279], [4.678581, -74.04857], [4.7255774, -74.03733], [4.67151, -74.04838], [4.58537, -74.16314], [4.6786757, -74.04354], [4.6654444, -74.049126], [4.65124, -74.10635], [4.714574, -74.063286], [4.70314, -74.04654], [4.676779, -74.04181], [4.7113466, -74.04748], [4.68487, -74.04446], [4.6773024, -74.1056], [4.6526155, -74.056206], [4.7273827, -74.0338], [4.666015, -74.04484], [4.700203, -74.04712], [4.704885, -74.02581], [4.70627, -74.03839], [4.7099743, -74.07165], [4.6384406, -74.074486], [4.674083, -74.047615], [4.672044, -74.05639], [4.689012, -74.05062], [4.694, -74.045], [4.7016506, -74.03138], [4.6772766, -74.07946], [4.66058, -74.13397], [4.6957164, -74.03914], [4.657716, -74.04816], [4.68563, -74.09231], [4.700838, -74.062256], [4.669, -74.049], [4.68817, -74.111176], [4.747378, -74.025345], [4.7508883, -74.09946], [4.682, -74.05], [4.687, -74.05], [4.672856, -74.05114], [4.663, -74.045], [4.68005, -74.05157], [4.72062, -74.02522], [4.6737685, -74.045], [4.74529, -74.03288], [4.71665, -74.0266], [4.63842, -74.06092], [4.6970115, -74.025116], [4.67061, -74.04294], [4.676351, -74.04289], [4.69394, -74.04555], [4.72435, -74.02353], [4.717, -74.022], [4.67381, -74.04812], [4.6762705, -74.044136], [4.67061, -74.04294], [4.66379, -74.05439], [4.67531, -74.05051], [4.65367, -74.05201], [4.673987, -74.042435], [4.64866, -74.05916], [4.59794, -74.16015], [4.687, -74.03], [4.657089, -74.1341], [4.6984205, -74.055916], [4.6186795, -74.06746], [4.7094607, -74.07034], [4.702543, -74.0352], [4.69504, -74.046936], [4.69355, -74.03628], [4.752615, -74.029785], [4.72964, -74.07187], [4.75426, -74.10438], [4.6732297, -74.05094], [4.6846757, -74.04633], [4.6706285, -74.04829], [4.674544,

# %%
# Create base map centered on Bogotá
m = folium.Map(location=[4.7110, -74.0721], zoom_start=12)

# Bin the latitude and longitude into grid cells (lattice)
lat_bins = np.linspace(apartments['latitud'].min(
), apartments['latitud'].max(), 60)  # Adjust number of bins as needed
lon_bins = np.linspace(
    apartments['longitud'].min(), apartments['longitud'].max(), 60)

apartments['lat_bin'] = pd.cut(apartments['latitud'], bins=lat_bins)
apartments['lon_bin'] = pd.cut(apartments['longitud'], bins=lon_bins)

# Aggregate rent price by these bins
apartments_grouped = apartments.groupby(['lat_bin', 'lon_bin']).agg(
    {'precio_arriendo': 'mean'}).reset_index()

# Calculate the center of each bin (for latitude and longitude)
apartments_grouped['lat_center'] = apartments_grouped['lat_bin'].apply(
    lambda x: x.mid)
apartments_grouped['lon_center'] = apartments_grouped['lon_bin'].apply(
    lambda x: x.mid)

# Normalize rent prices to use for color scaling
min_price = apartments_grouped['precio_arriendo'].min()
max_price = apartments_grouped['precio_arriendo'].max()

# Create a color map from green to red
colormap = mcolors.LinearSegmentedColormap.from_list(
    "rent_colormap", ['green', 'yellow', 'red'])

# Function to assign colors based on rent price


def get_color(price):
    # Normalize price to range between 0 and 1
    norm_price = (price - min_price) / (max_price - min_price)
    # Get the corresponding color from the colormap
    return mcolors.to_hex(colormap(norm_price))


# Add grid cells (rectangles) to the map
for index, row in apartments_grouped.iterrows():
    if pd.notna(row['precio_arriendo']):  # Ensure there is a price for the bin
        folium.Rectangle(
            bounds=[
                # Bottom-left corner of the rectangle
                [row['lat_bin'].left, row['lon_bin'].left],
                # Top-right corner of the rectangle
                [row['lat_bin'].right, row['lon_bin'].right]
            ],
            color=get_color(row['precio_arriendo']),
            fill=True,
            fill_opacity=0.6,
            popup=f"Avg Price: ${round(row['precio_arriendo'])}"
        ).add_to(m)

# Save the map as an HTML file
m.save('../visualizations/lattice_map.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7c87a623d06e63e5692e21dc8894ea50 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7c87a623d06e63e5692e21dc8894ea50&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7c87a623d06e63e5692e21dc8894ea50 = L.map(
#                 &quot;map_7c87a623d06e63e5692e21dc8894ea50&quot;,
#                 {
#                     center: [4.711, -74.0721],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a9e7ae9c51579286091dc30af8c7ac69 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a9e7ae9c51579286091dc30af8c7ac69.addTo(map_7c87a623d06e63e5692e21dc8894ea50);
#
#
#             var rectangle_fcd3f53a169e047e480d166a85762b90 = L.rectangle(
#                 [[4.489, -74.116], [4.494, -74.113]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#008000&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#008000&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7c87a623d06e63e5692e21dc8894ea50);
#
#
#         var popup_fc0871aa51e8a67c5aa8862893a94b9c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1e26d984eb83c0e70531ae4800550b43 = $(`&lt;div id=&quot;html_1e26d984eb83c0e70531ae4800550b43&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Avg Price: $600000&lt;/div&gt;`)[0];
#                 popup_fc0871aa51e8a67c5aa8862893a94b9c.setContent(html_1e26d984eb83c0e70531ae4800550b43);
#
#
#
#         rectangle_fcd3f53a169e047e480d166a85762b90.bindPopup(popup_fc0871aa51e8a67c5aa8862893a94b9c)
#         ;
#
#
#
#
#             var rectangle_a8cb98accbd9d8708909a973c7109f3c = L.rectangle(
#                 [[4.504, -74.106], [4.51, -74.103]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#008000&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#008000&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7c87a623d06e63e5692e21dc8894ea50);
#
#
#         var popup_5441117ebe76abd8bdf82ca95f3b3e3a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e48b0320814160f00ddfacf7ff951908 = $(`&lt;div id=&quot;html_e48b0320814160f00ddfacf7ff951908&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Avg Price: $600000&lt;/div&gt;`)[0];
#                 popup_5441117ebe76abd8bdf82ca95f3b3e3a.setContent(html_e48b0320814160f00ddfacf7ff951908);
#
#
#
#         rectangle_a8cb98accbd9d8708909a973c7109f3c.bindPopup(popup_5441117ebe76abd8bdf82ca95f3b3e3a)
#         ;
#
#
#
#
#             var rectangle_837660f1246245f960b2760182d676d5 = L.rectangle(
#                 [[4.504, -74.1], [4.51, -74.096]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#068300&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#068300&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7c87a623d06e63e5692e21dc8894ea50);
#
#
#         var popup_bea5f0c1c4701f867eec9aa2b35ca54d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_aca89cbd3afd8df18a8cd96949c53e7f = $(`&lt;div id=&quot;html_aca89cbd3afd8df18a8cd96949c53e7f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Avg Price: $800000&lt;/div&gt;`)[0];
#                 popup_bea5f0c1c4701f867eec9aa2b35ca54d.setContent(html_aca89cbd3afd8df18a8cd96949c53e7f);
#
#
#
#         rectangle_837660f1246245f960b2760182d676d5.bindPopup(popup_bea5f0c1c4701f867eec9aa2b35ca54d)
#         ;
#
#
#
#
#             var rectangle_05784e419e7db9d2e33b44396409d4b7 = L.rectangle(
#                 [[4.51, -74.09], [4.515, -74.086]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#008000&quot;,

# %%
# Create base map centered on Bogotá
m = folium.Map(location=[4.7110, -74.0721], zoom_start=12)

# Bin the latitude and longitude into grid cells (lattice)
lat_bins = np.linspace(apartments['latitud'].min(
), apartments['latitud'].max(), 75)  # Adjust number of bins as needed
lon_bins = np.linspace(
    apartments['longitud'].min(), apartments['longitud'].max(), 75)

apartments['lat_bin'] = pd.cut(apartments['latitud'], bins=lat_bins)
apartments['lon_bin'] = pd.cut(apartments['longitud'], bins=lon_bins)

# Aggregate rent price by these bins
apartments_grouped = apartments.groupby(['lat_bin', 'lon_bin']).agg(
    {'precio_arriendo': 'mean'}).reset_index()

# Calculate the center of each bin (for latitude and longitude)
apartments_grouped['lat_center'] = apartments_grouped['lat_bin'].apply(
    lambda x: x.mid)
apartments_grouped['lon_center'] = apartments_grouped['lon_bin'].apply(
    lambda x: x.mid)

# Normalize rent prices to use for color scaling
min_price = apartments_grouped['precio_arriendo'].min()
max_price = apartments_grouped['precio_arriendo'].max()

# Create a color map from green to red
colormap = mcolors.LinearSegmentedColormap.from_list(
    "rent_colormap", ['green', 'yellow', 'red'])

# Function to normalize using quantiles
def get_quantile_color(price):
    # Calculate quantiles of the rent price
    q10 = apartments_grouped['precio_arriendo'].quantile(
        0.10)  # 10th percentile
    q90 = apartments_grouped['precio_arriendo'].quantile(
        0.90)  # 90th percentile

    # Cap the price between the 10th and 90th percentiles
    if price < q10:
        price = q10
    elif price > q90:
        price = q90

    # Normalize price to range between 0 and 1 based on quantiles
    norm_price = (price - q10) / (q90 - q10)

    # Get color from the colormap
    return mcolors.to_hex(colormap(norm_price))


# Apply the quantile color mapping in the loop
for index, row in apartments_grouped.iterrows():
    if pd.notna(row['precio_arriendo']):  # Ensure there is a price for the bin
        folium.Rectangle(
            bounds=[
                # Bottom-left corner of the rectangle
                [row['lat_bin'].left, row['lon_bin'].left],
                # Top-right corner of the rectangle
                [row['lat_bin'].right, row['lon_bin'].right]
            ],
            color=get_quantile_color(row['precio_arriendo']),
            fill=True,
            fill_opacity=0.5,
            stroke=False,
            popup=f"Avg Price: ${round(row['precio_arriendo'])}"
        ).add_to(m)
        
# Save the map as an HTML file
m.save('../visualizations/lattice_map_quantile.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8e43e3fc9ebc2e106af7ca987b6f8981 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8e43e3fc9ebc2e106af7ca987b6f8981&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8e43e3fc9ebc2e106af7ca987b6f8981 = L.map(
#                 &quot;map_8e43e3fc9ebc2e106af7ca987b6f8981&quot;,
#                 {
#                     center: [4.711, -74.0721],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eded3b41824074141c68bc7f3a3fb53f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_eded3b41824074141c68bc7f3a3fb53f.addTo(map_8e43e3fc9ebc2e106af7ca987b6f8981);
#
#
#             var rectangle_9c30ac3e2d0d0a2fdc5166b502c8c0f5 = L.rectangle(
#                 [[4.489, -74.115], [4.493, -74.112]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#008000&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#008000&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: false, &quot;weight&quot;: 3}
#             ).addTo(map_8e43e3fc9ebc2e106af7ca987b6f8981);
#
#
#         var popup_310dd95020f61efa2ce2e4d0a33b8a66 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e2cbc39756d09675d43298a8562052c0 = $(`&lt;div id=&quot;html_e2cbc39756d09675d43298a8562052c0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Avg Price: $600000&lt;/div&gt;`)[0];
#                 popup_310dd95020f61efa2ce2e4d0a33b8a66.setContent(html_e2cbc39756d09675d43298a8562052c0);
#
#
#
#         rectangle_9c30ac3e2d0d0a2fdc5166b502c8c0f5.bindPopup(popup_310dd95020f61efa2ce2e4d0a33b8a66)
#         ;
#
#
#
#
#             var rectangle_f149481e3647565e1e823143bb94d1ee = L.rectangle(
#                 [[4.501, -74.107], [4.505, -74.104]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#008000&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#008000&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: false, &quot;weight&quot;: 3}
#             ).addTo(map_8e43e3fc9ebc2e106af7ca987b6f8981);
#
#
#         var popup_4d6c219bb0b0b22f21bb8ef930f6ae40 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dc386bc5d9a1f893c878f00fd2d18008 = $(`&lt;div id=&quot;html_dc386bc5d9a1f893c878f00fd2d18008&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Avg Price: $600000&lt;/div&gt;`)[0];
#                 popup_4d6c219bb0b0b22f21bb8ef930f6ae40.setContent(html_dc386bc5d9a1f893c878f00fd2d18008);
#
#
#
#         rectangle_f149481e3647565e1e823143bb94d1ee.bindPopup(popup_4d6c219bb0b0b22f21bb8ef930f6ae40)
#         ;
#
#
#
#
#             var rectangle_06e4e8cf306376a01e889c11d2296970 = L.rectangle(
#                 [[4.505, -74.101], [4.51, -74.099]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#008000&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#008000&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: false, &quot;weight&quot;: 3}
#             ).addTo(map_8e43e3fc9ebc2e106af7ca987b6f8981);
#
#
#         var popup_3ea0f18cc080df1941e3e9200ddbfe44 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_393abd780c5ae8a3fc9296f838ab8c3a = $(`&lt;div id=&quot;html_393abd780c5ae8a3fc9296f838ab8c3a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Avg Price: $800000&lt;/div&gt;`)[0];
#                 popup_3ea0f18cc080df1941e3e9200ddbfe44.setContent(html_393abd780c5ae8a3fc9296f838ab8c3a);
#
#
#
#         rectangle_06e4e8cf306376a01e889c11d2296970.bindPopup(popup_3ea0f18cc080df1941e3e9200ddbfe44)
#         ;
#
#
#
#
#             var rectangle_9ba30909d6d87cb54ac72e7865c21aa2 = L.rectangle(
#                 [[4.514, -74.091], [4.518, -74.088]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#00800

# %% [markdown]
# # create a marker cluster
# marker_cluster = MarkerCluster().add_to(m)
#
# # Add points to the cluster
# for index, row in apartments.iterrows():
#     folium.Marker(
#         location=[row['latitud'], row['longitud']],
#         popup=f"${row['precio_arriendo']}",
#     ).add_to(marker_cluster)
#
# m.save('../reports/maps/apartments.html')
# m
